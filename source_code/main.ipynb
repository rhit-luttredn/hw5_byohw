# %%
import os
import math
from statistics import mean

import neat
import visualize
import pandas as pd
import numpy as np
import json
from threading import Thread

# %%
def eval_one_genome(genome_id, genome, config, x, y):
    xi = x.copy()
    net = neat.nn.FeedForwardNetwork.create(genome, config)
    
    # keep feeding the board to the network until the puzzle is solved
    accuracies = []
    # for xi, yi in zip(x, y):
    cells_to_solve = xi.count(-0.5)
    num_correct = 0
    while -0.5 in xi:
        output = net.activate(xi)
        indices = np.flip(np.argsort(output))

        # find idx of most confident prediction that corresponds to a 0 cell
        max_idx = -1
        for idx in indices:
            if xi[math.floor(idx/9)] == -0.5:
                max_idx = idx
                break
        
        board_idx = math.floor(max_idx / 9)
        number = max_idx % 9 + 1
        xi[board_idx] = y[board_idx]
        num_correct += int(number / 9 - 0.5 == y[board_idx])
    accuracies.append(num_correct / cells_to_solve)

    # Calculate the fitness
    genome.fitness = mean(accuracies)
    # print(f"genome: {genome_id}\t fitness: {genome.fitness}")


# def eval_genomes(genomes, config, data, sample_n):
def eval_genomes(genomes, config):
    sample = train.sample(n=1)
    x = sample.quizzes.array[0]
    y = sample.solutions.array[0]
    threads = []
    for genome_id, genome in genomes:
        t = Thread(target=eval_one_genome, args=[genome_id, genome, config, x, y])
        t.start()
        threads.append(t)
    
    for t in threads:
        t.join()
        

def run(config_file, checkpoint=None):
    print("Configuring Settings")
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    if checkpoint == None:
        # No checkpoint specified, create a new population
        print("Creating Population")
        p = neat.Population(config)

        # Add a stdout reporter to show progress in the terminal.
        p.add_reporter(neat.StdOutReporter(True))
        stats = neat.StatisticsReporter()
        p.add_reporter(stats)
        p.add_reporter(neat.Checkpointer(generation_interval=1, time_interval_seconds=500, filename_prefix="checkpoints/neat-checkpoint-"))
    else:
        # Restore a checkpoint
        print("Restoring Population from Checkpoint")
        p = neat.restore_checkpoint(checkpoint)

    # Run for up to 300 generations.
    print("Training Network")
    # winner = p.run(lambda genomes, config: eval_genomes(genomes, config, train, 1), n=300)
    winner = p.run(eval_genomes, n=300)
    print("Finished Training")

    # TODO: Run p on test data and get the winner that way

    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(winner))

    # TODO: Rewrite this so that it actually fits the new model
    # Show output of the most fit genome against training data.
    print('\nOutput:')
    winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
    for xi, yi in zip(train_x, train_y):
        output = winner_net.activate(xi)
        print("input {!r}, expected output {!r}, got {!r}".format(xi, yi, output))

    node_names = {-1: 'A', -2: 'B', 0: 'A XOR B'}
    visualize.draw_net(config, winner, True, node_names=node_names)
    # visualize.draw_net(config, winner, True, node_names=node_names, prune_unused=True)
    visualize.plot_stats(stats, ylog=False, view=True)
    visualize.plot_species(stats, view=True)

    # p = neat.Checkpointer.restore_checkpoint('checkpoints/neat-checkpoint-4')
    # p.run(eval_genomes, 10)

# %%
# load data
data = pd.read_csv("sudoku_cleaned.csv")
data = data.apply(lambda x: x.apply(json.loads))

# %%
# get test and train sets
FRAC_TRAIN = 0.5

data = data.sample(frac=1).reset_index(drop=True)
train = data.head(math.floor(data.shape[0] * FRAC_TRAIN))
train_x = train["quizzes"]
train_y = train["solutions"]

test = data.tail(math.ceil(data.shape[0] * FRAC_TRAIN))
test_x = test["quizzes"]
test_y = test["solutions"]

# %%
# Determine path to configuration file. This path manipulation is
# here so that the script will run successfully regardless of the
# current working directory.
# local_dir = os.path.dirname(__file__)
# config_path = os.path.join(local_dir, 'properties.config')
config_path = 'properties.config'
run(config_path)
# Out:
# Configuring Settings
# Creating Population
# Training Network
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.10087 stdev: 0.03955
# Best fitness: 0.21739 - size: (729, 59049) - species 1 - id 29
# Average adjusted fitness: 0.079
# Mean genetic distance 1.166, standard deviation 0.112
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50      0.2    0.079     0
# Total extinctions: 0
# Generation time: 199.856 sec
# Saving checkpoint to checkpoints/neat-checkpoint-0
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.11280 stdev: 0.04396
# Best fitness: 0.24000 - size: (729, 58748) - species 1 - id 72
# Average adjusted fitness: 0.093
# Mean genetic distance 1.228, standard deviation 0.069
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50      0.2    0.093     0
# Total extinctions: 0
# Generation time: 197.579 sec (198.717 average)
# Saving checkpoint to checkpoints/neat-checkpoint-1
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.10449 stdev: 0.04215
# Best fitness: 0.22449 - size: (729, 58492) - species 1 - id 120
# Average adjusted fitness: 0.084
# Mean genetic distance 1.281, standard deviation 0.075
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50      0.2    0.084     1
# Total extinctions: 0
# Generation time: 184.821 sec (194.085 average)
# Saving checkpoint to checkpoints/neat-checkpoint-2
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.11826 stdev: 0.04105
# Best fitness: 0.21739 - size: (729, 58147) - species 1 - id 188
# Average adjusted fitness: 0.075
# Mean genetic distance 1.330, standard deviation 0.082
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50      0.2    0.075     2
# Total extinctions: 0
# Generation time: 181.131 sec (190.847 average)
# Saving checkpoint to checkpoints/neat-checkpoint-3
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.11292 stdev: 0.04231
# Best fitness: 0.20833 - size: (729, 57856) - species 1 - id 198
# Average adjusted fitness: 0.071
# Mean genetic distance 1.293, standard deviation 0.178
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50      0.2    0.071     3
# Total extinctions: 0
# Generation time: 180.943 sec (188.866 average)
# Saving checkpoint to checkpoints/neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.12000 stdev: 0.04791
# Best fitness: 0.25532 - size: (729, 57856) - species 1 - id 198
# Average adjusted fitness: 0.099
# Mean genetic distance 1.415, standard deviation 0.099
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    50      0.3    0.099     0
# Total extinctions: 0
# Generation time: 183.831 sec (188.027 average)
# Saving checkpoint to checkpoints/neat-checkpoint-5
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 0.10913 stdev: 0.04632
# Best fitness: 0.21739 - size: (729, 57298) - species 1 - id 334
# Average adjusted fitness: 0.109
# Mean genetic distance 1.357, standard deviation 0.181
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    50      0.2    0.109     1
# Total extinctions: 0
# Generation time: 175.935 sec (186.299 average)
# Saving checkpoint to checkpoints/neat-checkpoint-6
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.10125 stdev: 0.04584
# Best fitness: 0.18750 - size: (729, 56964) - species 1 - id 357
# Average adjusted fitness: 0.101
# Mean genetic distance 1.314, standard deviation 0.223
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    50      0.2    0.101     2
# Total extinctions: 0
# Generation time: 181.659 sec (185.719 average)
# Saving checkpoint to checkpoints/neat-checkpoint-7
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 0.11830 stdev: 0.05301
# Best fitness: 0.25532 - size: (729, 56752) - species 1 - id 400
# Average adjusted fitness: 0.076
# Mean genetic distance 1.443, standard deviation 0.149
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    50      0.3    0.076     3
# Total extinctions: 0
# Generation time: 184.490 sec (185.583 average)
# Saving checkpoint to checkpoints/neat-checkpoint-8
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 0.12625 stdev: 0.04278
# Best fitness: 0.27083 - size: (729, 56581) - species 1 - id 473
# Average adjusted fitness: 0.105
# Mean genetic distance 1.486, standard deviation 0.113
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    50      0.3    0.105     0
# Total extinctions: 0
# Generation time: 180.088 sec (185.033 average)
# Saving checkpoint to checkpoints/neat-checkpoint-9
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 0.12851 stdev: 0.04563
# Best fitness: 0.25532 - size: (730, 56276) - species 1 - id 496
# Average adjusted fitness: 0.086
# Mean genetic distance 1.517, standard deviation 0.118
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    50      0.3    0.086     1
# Total extinctions: 0
# Generation time: 175.154 sec (182.563 average)
# Saving checkpoint to checkpoints/neat-checkpoint-10
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 0.09388 stdev: 0.04415
# Best fitness: 0.20408 - size: (729, 56208) - species 1 - id 522
# Average adjusted fitness: 0.073
# Mean genetic distance 1.395, standard deviation 0.280
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    50      0.2    0.073     2
# Total extinctions: 0
# Generation time: 179.380 sec (180.743 average)
# Saving checkpoint to checkpoints/neat-checkpoint-11
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 0.09745 stdev: 0.03925
# Best fitness: 0.17021 - size: (729, 55714) - species 1 - id 611
# Average adjusted fitness: 0.076
# Mean genetic distance 1.554, standard deviation 0.123
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    50      0.2    0.076     3
# Total extinctions: 0
# Generation time: 186.282 sec (180.890 average)
# Saving checkpoint to checkpoints/neat-checkpoint-12
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 0.11106 stdev: 0.04408
# Best fitness: 0.21277 - size: (729, 55400) - species 1 - id 633
# Average adjusted fitness: 0.069
# Mean genetic distance 1.571, standard deviation 0.165
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    50      0.2    0.069     4
# Total extinctions: 0
# Generation time: 220.030 sec (184.779 average)
# Saving checkpoint to checkpoints/neat-checkpoint-13
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 0.14043 stdev: 0.04661
# Best fitness: 0.27660 - size: (729, 55171) - species 1 - id 691
# Average adjusted fitness: 0.098
# Mean genetic distance 1.553, standard deviation 0.136
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    50      0.3    0.098     0
# Total extinctions: 0
# Generation time: 169.335 sec (183.619 average)
# Saving checkpoint to checkpoints/neat-checkpoint-14
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 0.11087 stdev: 0.04176
# Best fitness: 0.21739 - size: (729, 54980) - species 1 - id 730
# Average adjusted fitness: 0.067
# Mean genetic distance 1.515, standard deviation 0.181
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    50      0.2    0.067     1
# Total extinctions: 0
# Generation time: 170.764 sec (182.312 average)
# Saving checkpoint to checkpoints/neat-checkpoint-15
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 0.14652 stdev: 0.04472
# Best fitness: 0.26087 - size: (730, 54659) - species 1 - id 783
# Average adjusted fitness: 0.081
# Mean genetic distance 1.499, standard deviation 0.130
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    50      0.3    0.081     2
# Total extinctions: 0
# Generation time: 168.615 sec (181.580 average)
# Saving checkpoint to checkpoints/neat-checkpoint-16
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 0.09522 stdev: 0.04122
# Best fitness: 0.21739 - size: (729, 54356) - species 1 - id 851
# Average adjusted fitness: 0.073
# Mean genetic distance 1.586, standard deviation 0.116
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    50      0.2    0.073     3
# Total extinctions: 0
# Generation time: 168.269 sec (180.241 average)
# Saving checkpoint to checkpoints/neat-checkpoint-17
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 0.10292 stdev: 0.04831
# Best fitness: 0.20833 - size: (729, 54160) - species 1 - id 897
# Average adjusted fitness: 0.082
# Mean genetic distance 1.498, standard deviation 0.171
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    50      0.2    0.082     4
# Total extinctions: 0
# Generation time: 166.954 sec (178.487 average)
# Saving checkpoint to checkpoints/neat-checkpoint-18
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 0.08213 stdev: 0.03661
# Best fitness: 0.19149 - size: (730, 53913) - species 1 - id 915
# Average adjusted fitness: 0.061
# Mean genetic distance 1.468, standard deviation 0.189
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    50      0.2    0.061     5
# Total extinctions: 0
# Generation time: 166.164 sec (177.095 average)
# Saving checkpoint to checkpoints/neat-checkpoint-19
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 0.13021 stdev: 0.04415
# Best fitness: 0.25532 - size: (731, 53756) - species 1 - id 970
# Average adjusted fitness: 0.109
# Mean genetic distance 1.557, standard deviation 0.120
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    50      0.3    0.109     6
# Total extinctions: 0
# Generation time: 166.818 sec (176.261 average)
# Saving checkpoint to checkpoints/neat-checkpoint-20
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 0.12170 stdev: 0.03405
# Best fitness: 0.21277 - size: (731, 53410) - species 1 - id 1024
# Average adjusted fitness: 0.100
# Mean genetic distance 1.516, standard deviation 0.199
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    50      0.2    0.100     7
# Total extinctions: 0
# Generation time: 165.570 sec (174.880 average)
# Saving checkpoint to checkpoints/neat-checkpoint-21
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 0.12936 stdev: 0.05209
# Best fitness: 0.23404 - size: (731, 53296) - species 1 - id 1076
# Average adjusted fitness: 0.108
# Mean genetic distance 1.428, standard deviation 0.319
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    50      0.2    0.108     8
# Total extinctions: 0
# Generation time: 164.773 sec (172.729 average)
# Saving checkpoint to checkpoints/neat-checkpoint-22
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 0.14750 stdev: 0.05032
# Best fitness: 0.27083 - size: (730, 52957) - species 1 - id 1109
# Average adjusted fitness: 0.085
# Mean genetic distance 1.430, standard deviation 0.225
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    50      0.3    0.085     9
# Total extinctions: 0
# Generation time: 166.994 sec (167.426 average)
# Saving checkpoint to checkpoints/neat-checkpoint-23
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 0.08383 stdev: 0.02771
# Best fitness: 0.12766 - size: (731, 52735) - species 1 - id 1162
# Average adjusted fitness: 0.063
# Mean genetic distance 1.506, standard deviation 0.167
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    50      0.1    0.063    10
# Total extinctions: 0
# Generation time: 163.830 sec (166.875 average)
# Saving checkpoint to checkpoints/neat-checkpoint-24
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 0.12500 stdev: 0.03656
# Best fitness: 0.25000 - size: (731, 52492) - species 1 - id 1246
# Average adjusted fitness: 0.062
# Mean genetic distance 1.502, standard deviation 0.204
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    50      0.2    0.062    11
# Total extinctions: 0
# Generation time: 164.134 sec (166.212 average)
# Saving checkpoint to checkpoints/neat-checkpoint-25
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 0.10333 stdev: 0.03952
# Best fitness: 0.22917 - size: (730, 52244) - species 1 - id 1251
# Average adjusted fitness: 0.082
# Mean genetic distance 1.527, standard deviation 0.191
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    50      0.2    0.082    12
# Total extinctions: 0
# Generation time: 165.350 sec (165.886 average)
# Saving checkpoint to checkpoints/neat-checkpoint-26
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 0.16681 stdev: 0.04551
# Best fitness: 0.29787 - size: (731, 52006) - species 1 - id 1332
# Average adjusted fitness: 0.082
# Mean genetic distance 1.534, standard deviation 0.229
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    50      0.3    0.082     0
# Total extinctions: 0
# Generation time: 161.274 sec (165.186 average)
# Saving checkpoint to checkpoints/neat-checkpoint-27
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 0.15143 stdev: 0.04435
# Best fitness: 0.24490 - size: (731, 51823) - species 1 - id 1361
# Average adjusted fitness: 0.111
# Mean genetic distance 1.589, standard deviation 0.132
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    50      0.2    0.111     1
# Total extinctions: 0
# Generation time: 166.572 sec (165.148 average)
# Saving checkpoint to checkpoints/neat-checkpoint-28
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 0.10292 stdev: 0.04154
# Best fitness: 0.20833 - size: (730, 51791) - species 1 - id 1437
# Average adjusted fitness: 0.082
# Mean genetic distance 1.413, standard deviation 0.193
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    50      0.2    0.082     2
# Total extinctions: 0
# Generation time: 161.298 sec (164.661 average)
# Saving checkpoint to checkpoints/neat-checkpoint-29
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 0.13404 stdev: 0.04705
# Best fitness: 0.23404 - size: (730, 51471) - species 1 - id 1473
# Average adjusted fitness: 0.091
# Mean genetic distance 1.407, standard deviation 0.170
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    50      0.2    0.091     3
# Total extinctions: 0
# Generation time: 161.163 sec (164.096 average)
# Saving checkpoint to checkpoints/neat-checkpoint-30
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 0.12766 stdev: 0.03900
# Best fitness: 0.21277 - size: (731, 51462) - species 1 - id 1499
# Average adjusted fitness: 0.085
# Mean genetic distance 1.359, standard deviation 0.168
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    50      0.2    0.085     4
# Total extinctions: 0
# Generation time: 165.294 sec (164.068 average)
# Saving checkpoint to checkpoints/neat-checkpoint-31
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 0.11702 stdev: 0.03859
# Best fitness: 0.19149 - size: (729, 51114) - species 1 - id 1540
# Average adjusted fitness: 0.096
# Mean genetic distance 1.386, standard deviation 0.187
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    50      0.2    0.096     5
# Total extinctions: 0
# Generation time: 160.078 sec (163.599 average)
# Saving checkpoint to checkpoints/neat-checkpoint-32
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 0.09200 stdev: 0.03323
# Best fitness: 0.20000 - size: (730, 50993) - species 1 - id 1599
# Average adjusted fitness: 0.072
# Mean genetic distance 1.342, standard deviation 0.234
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    50      0.2    0.072     6
# Total extinctions: 0
# Generation time: 160.155 sec (162.915 average)
# Saving checkpoint to checkpoints/neat-checkpoint-33
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 0.11532 stdev: 0.03736
# Best fitness: 0.19149 - size: (729, 50825) - species 1 - id 1662
# Average adjusted fitness: 0.073
# Mean genetic distance 1.405, standard deviation 0.191
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    50      0.2    0.073     7
# Total extinctions: 0
# Generation time: 158.158 sec (162.348 average)
# Saving checkpoint to checkpoints/neat-checkpoint-34
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 0.10553 stdev: 0.04339
# Best fitness: 0.19149 - size: (730, 50583) - species 1 - id 1688
# Average adjusted fitness: 0.084
# Mean genetic distance 1.499, standard deviation 0.159
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    50      0.2    0.084     8
# Total extinctions: 0
# Generation time: 158.796 sec (161.814 average)
# Saving checkpoint to checkpoints/neat-checkpoint-35
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 0.11469 stdev: 0.03625
# Best fitness: 0.20408 - size: (730, 50396) - species 1 - id 1752
# Average adjusted fitness: 0.074
# Mean genetic distance 1.502, standard deviation 0.215
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    50      0.2    0.074     9
# Total extinctions: 0
# Generation time: 159.920 sec (161.271 average)
# Saving checkpoint to checkpoints/neat-checkpoint-36
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 0.14292 stdev: 0.03997
# Best fitness: 0.22917 - size: (732, 50160) - species 1 - id 1794
# Average adjusted fitness: 0.080
# Mean genetic distance 1.478, standard deviation 0.194
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    50      0.2    0.080    10
# Total extinctions: 0
# Generation time: 158.362 sec (160.980 average)
# Saving checkpoint to checkpoints/neat-checkpoint-37
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 0.11149 stdev: 0.04027
# Best fitness: 0.21277 - size: (729, 49960) - species 1 - id 1841
# Average adjusted fitness: 0.090
# Mean genetic distance 1.424, standard deviation 0.227
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    50      0.2    0.090    11
# Total extinctions: 0
# Generation time: 156.592 sec (159.982 average)
# Saving checkpoint to checkpoints/neat-checkpoint-38
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 0.09870 stdev: 0.03538
# Best fitness: 0.19565 - size: (729, 49734) - species 1 - id 1897
# Average adjusted fitness: 0.077
# Mean genetic distance 1.465, standard deviation 0.196
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    50      0.2    0.077    12
# Total extinctions: 0
# Generation time: 155.854 sec (159.437 average)
# Saving checkpoint to checkpoints/neat-checkpoint-39
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 0.12625 stdev: 0.03546
# Best fitness: 0.20833 - size: (729, 49614) - species 1 - id 1933
# Average adjusted fitness: 0.085
# Mean genetic distance 1.488, standard deviation 0.134
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    50      0.2    0.085    13
# Total extinctions: 0
# Generation time: 158.750 sec (159.196 average)
# Saving checkpoint to checkpoints/neat-checkpoint-40
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 0.11191 stdev: 0.04251
# Best fitness: 0.25532 - size: (729, 49408) - species 1 - id 1999
# Average adjusted fitness: 0.091
# Mean genetic distance 1.557, standard deviation 0.116
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    50      0.3    0.091    14
# Total extinctions: 0
# Generation time: 157.115 sec (158.378 average)
# Saving checkpoint to checkpoints/neat-checkpoint-41
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 0.09625 stdev: 0.03862
# Best fitness: 0.20833 - size: (730, 49212) - species 1 - id 2027
# Average adjusted fitness: 0.075
# Mean genetic distance 1.587, standard deviation 0.153
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    50      0.2    0.075    15
# Total extinctions: 0
# Generation time: 155.406 sec (157.911 average)
# Saving checkpoint to checkpoints/neat-checkpoint-42
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 0.10340 stdev: 0.03535
# Best fitness: 0.17021 - size: (729, 48993) - species 1 - id 2077
# Average adjusted fitness: 0.061
# Mean genetic distance 1.583, standard deviation 0.233
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    50      0.2    0.061    16
# Total extinctions: 0
# Generation time: 153.471 sec (157.242 average)
# Saving checkpoint to checkpoints/neat-checkpoint-43
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 0.14571 stdev: 0.04490
# Best fitness: 0.26531 - size: (731, 48842) - species 1 - id 2132
# Average adjusted fitness: 0.084
# Mean genetic distance 1.404, standard deviation 0.284
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    50      0.3    0.084    17
# Total extinctions: 0
# Generation time: 155.727 sec (156.999 average)
# Saving checkpoint to checkpoints/neat-checkpoint-44
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 0.12667 stdev: 0.03883
# Best fitness: 0.22917 - size: (729, 48551) - species 1 - id 2175
# Average adjusted fitness: 0.064
# Mean genetic distance 1.529, standard deviation 0.206
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    50      0.2    0.064    18
# Total extinctions: 0
# Generation time: 154.468 sec (156.567 average)
# Saving checkpoint to checkpoints/neat-checkpoint-45
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 0.11583 stdev: 0.04065
# Best fitness: 0.20833 - size: (729, 48369) - species 1 - id 2216
# Average adjusted fitness: 0.074
# Mean genetic distance 1.616, standard deviation 0.153
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    50      0.2    0.074    19
# Total extinctions: 0
# Generation time: 155.302 sec (156.105 average)
# Saving checkpoint to checkpoints/neat-checkpoint-46
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 0.10044 stdev: 0.03778
# Best fitness: 0.20000 - size: (729, 48149) - species 1 - id 2285
# Average adjusted fitness: 0.056
# Mean genetic distance 1.408, standard deviation 0.223
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    50      0.2    0.056    20
# Total extinctions: 0
# Generation time: 151.253 sec (155.394 average)
# Saving checkpoint to checkpoints/neat-checkpoint-47
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 0.15234 stdev: 0.04067
# Best fitness: 0.23404 - size: (729, 48029) - species 1 - id 2333
# Average adjusted fitness: 0.089
# Mean genetic distance 1.404, standard deviation 0.277
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    50      0.2    0.089    21
# Total extinctions: 0
# Generation time: 152.885 sec (155.023 average)
# Saving checkpoint to checkpoints/neat-checkpoint-48
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 0.11362 stdev: 0.04937
# Best fitness: 0.31915 - size: (729, 47905) - species 1 - id 2395
# Average adjusted fitness: 0.071
# Mean genetic distance 1.608, standard deviation 0.120
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49    50      0.3    0.071     0
# Total extinctions: 0
# Generation time: 152.338 sec (154.672 average)
# Saving checkpoint to checkpoints/neat-checkpoint-49
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 0.12958 stdev: 0.03468
# Best fitness: 0.20833 - size: (729, 47565) - species 1 - id 2410
# Average adjusted fitness: 0.088
# Mean genetic distance 1.592, standard deviation 0.138
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    50      0.2    0.088     1
# Total extinctions: 0
# Generation time: 152.517 sec (154.048 average)
# Saving checkpoint to checkpoints/neat-checkpoint-50
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 0.09489 stdev: 0.03690
# Best fitness: 0.19149 - size: (729, 47433) - species 1 - id 2465
# Average adjusted fitness: 0.074
# Mean genetic distance 1.661, standard deviation 0.112
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    50      0.2    0.074     2
# Total extinctions: 0
# Generation time: 151.910 sec (153.528 average)
# Saving checkpoint to checkpoints/neat-checkpoint-51
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 0.11417 stdev: 0.03980
# Best fitness: 0.20833 - size: (729, 47229) - species 1 - id 2511
# Average adjusted fitness: 0.072
# Mean genetic distance 1.622, standard deviation 0.158
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    50      0.2    0.072     3
# Total extinctions: 0
# Generation time: 149.889 sec (152.976 average)
# Saving checkpoint to checkpoints/neat-checkpoint-52
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 0.07429 stdev: 0.03208
# Best fitness: 0.18367 - size: (730, 47090) - species 1 - id 2588
# Average adjusted fitness: 0.054
# Mean genetic distance 1.560, standard deviation 0.194
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    50      0.2    0.054     4
# Total extinctions: 0
# Generation time: 155.323 sec (153.161 average)
# Saving checkpoint to checkpoints/neat-checkpoint-53
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 0.10522 stdev: 0.03698
# Best fitness: 0.19565 - size: (729, 46954) - species 1 - id 2601
# Average adjusted fitness: 0.062
# Mean genetic distance 1.529, standard deviation 0.207
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    50      0.2    0.062     5
# Total extinctions: 0
# Generation time: 151.305 sec (152.719 average)
# Saving checkpoint to checkpoints/neat-checkpoint-54
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 0.11489 stdev: 0.04277
# Best fitness: 0.21277 - size: (730, 46847) - species 1 - id 2608
# Average adjusted fitness: 0.094
# Mean genetic distance 1.525, standard deviation 0.244
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    50      0.2    0.094     6
# Total extinctions: 0
# Generation time: 150.279 sec (152.300 average)
# Saving checkpoint to checkpoints/neat-checkpoint-55
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 0.11583 stdev: 0.03956
# Best fitness: 0.20833 - size: (731, 46622) - species 1 - id 2693
# Average adjusted fitness: 0.074
# Mean genetic distance 1.611, standard deviation 0.156
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    50      0.2    0.074     7
# Total extinctions: 0
# Generation time: 150.299 sec (151.800 average)
# Saving checkpoint to checkpoints/neat-checkpoint-56
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 0.11702 stdev: 0.02925
# Best fitness: 0.17021 - size: (729, 46420) - species 1 - id 2749
# Average adjusted fitness: 0.074
# Mean genetic distance 1.564, standard deviation 0.125
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    50      0.2    0.074     8
# Total extinctions: 0
# Generation time: 149.610 sec (151.635 average)
# Saving checkpoint to checkpoints/neat-checkpoint-57
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 0.12085 stdev: 0.02837
# Best fitness: 0.19149 - size: (730, 46327) - species 1 - id 2812
# Average adjusted fitness: 0.057
# Mean genetic distance 1.563, standard deviation 0.106
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    50      0.2    0.057     9
# Total extinctions: 0
# Generation time: 148.209 sec (151.168 average)
# Saving checkpoint to checkpoints/neat-checkpoint-58
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 0.12426 stdev: 0.03306
# Best fitness: 0.21277 - size: (729, 46120) - species 1 - id 2868
# Average adjusted fitness: 0.060
# Mean genetic distance 1.598, standard deviation 0.090
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    50      0.2    0.060    10
# Total extinctions: 0
# Generation time: 149.188 sec (150.853 average)
# Saving checkpoint to checkpoints/neat-checkpoint-59
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 0.14833 stdev: 0.03878
# Best fitness: 0.22917 - size: (732, 45991) - species 1 - id 2887
# Average adjusted fitness: 0.065
# Mean genetic distance 1.615, standard deviation 0.138
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    50      0.2    0.065    11
# Total extinctions: 0
# Generation time: 147.694 sec (150.371 average)
# Saving checkpoint to checkpoints/neat-checkpoint-60
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 0.12851 stdev: 0.04482
# Best fitness: 0.25532 - size: (731, 45812) - species 1 - id 2963
# Average adjusted fitness: 0.086
# Mean genetic distance 1.515, standard deviation 0.184
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    50      0.3    0.086    12
# Total extinctions: 0
# Generation time: 153.839 sec (150.564 average)
# Saving checkpoint to checkpoints/neat-checkpoint-61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <module>
#       1 # Determine path to configuration file. This path manipulation is
#       2 # here so that the script will run successfully regardless of the
#       3 # current working directory.
#       4 # local_dir = os.path.dirname(__file__)
#       5 # config_path = os.path.join(local_dir, 'properties.config')
#       6 config_path = 'properties.config'
# ----> 7 run(config_path)
#
# c:\Users\luttredn\Desktop\CSSE490 Bio\HW5\hw5_byohw\source_code\main.ipynb Cell 4' in run(config_file, checkpoint)
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=101'>102</a> print("Training Network")
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=102'>103</a> # winner = p.run(lambda genomes, config: eval_genomes(genomes, config, train, 1), n=300)
# --> <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=103'>104</a> winner = p.run(eval_genomes, n=300)
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=104'>105</a> print("Finished Training")
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=106'>107</a> # TODO: Run p on test data and get the winner that way
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=107'>108</a>
#     <a href='vscode-notebook-cell:/c%3A/Users/luttredn/Desktop/CSSE490%20Bio/HW5/hw5_byohw/source_code/main.ipynb#ch0000003?line=108'>109</a> # Display the winning genome.
#
# File C:\Python39\lib\site-packages\neat\population.py:129, in Population.run(self, fitness_function, n)
#     <a href='file:///c%3A/Python39/lib/site-packages/neat/population.py?line=125'>126</a>     # Divide the new population into species.
#     <a href='file:///c%3A/Python39/lib/site-packages/neat/population.py?line=126'>127</a>     self.species.speciate(self.config, self.population, self.generation)
# --> <a href='file:///c%3A/Python39/lib/site-packages/neat/population.py?line=128'>129</a>     self.reporters.end_generation(self.config, self.population, self.species)
#     <a href='file:///c%3A/Python39/lib/site-packages/neat/population.py?line=130'>131</a>     self.generation += 1
#     <a href='file:///c%3A/Python39/lib/site-packages/neat/population.py?line=132'>133</a> if self.config.no_fitness_termination:
#
# File C:\Python39\lib\site-packages\neat\reporting.py:36, in ReporterSet.end_generation(self, config, population, species_set)
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/reporting.py?line=33'>34</a> def end_generation(self, config, population, species_set):
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/reporting.py?line=34'>35</a>     for r in self.reporters:
# ---> <a href='file:///c%3A/Python39/lib/site-packages/neat/reporting.py?line=35'>36</a>         r.end_generation(config, population, species_set)
#
# File C:\Python39\lib\site-packages\neat\checkpoint.py:59, in Checkpointer.end_generation(self, config, population, species_set)
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=55'>56</a>         checkpoint_due = True
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=57'>58</a> if checkpoint_due:
# ---> <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=58'>59</a>     self.save_checkpoint(config, population, species_set, self.current_generation)
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=59'>60</a>     self.last_generation_checkpoint = self.current_generation
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=60'>61</a>     self.last_time_checkpoint = time.time()
#
# File C:\Python39\lib\site-packages\neat\checkpoint.py:70, in Checkpointer.save_checkpoint(self, config, population, species_set, generation)
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=67'>68</a> with gzip.open(filename, 'w', compresslevel=5) as f:
#      <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=68'>69</a>     data = (generation, config, population, species_set, random.getstate())
# ---> <a href='file:///c%3A/Python39/lib/site-packages/neat/checkpoint.py?line=69'>70</a>     pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
#
# File C:\Python39\lib\gzip.py:288, in GzipFile.write(self, data)
#     <a href='file:///c%3A/Python39/lib/gzip.py?line=284'>285</a>     length = data.nbytes
#     <a href='file:///c%3A/Python39/lib/gzip.py?line=286'>287</a> if length > 0:
# --> <a href='file:///c%3A/Python39/lib/gzip.py?line=287'>288</a>     self.fileobj.write(self.compress.compress(data))
#     <a href='file:///c%3A/Python39/lib/gzip.py?line=288'>289</a>     self.size += length
#     <a href='file:///c%3A/Python39/lib/gzip.py?line=289'>290</a>     self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:
